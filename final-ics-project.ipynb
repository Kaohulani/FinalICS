# %% [markdown]
# <a href="https://www.kaggle.com/code/kaohulanipalakiko/final-ics-project?scriptVersionId=129366172" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
print("Setup Complete")
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# Setup Complete

# %%
# Set up code checking
from learntools.core import binder
binder.bind(globals())
from learntools.data_viz_to_coder.ex7 import *
print("Setup Complete")
# Out:
# Setup Complete

# %%
# Check for a dataset with a CSV file
step_1.check()
# Out:
# Correct:

# %%
# Fill in the line below: Specify the path of the CSV file to read
my_filepath = '/kaggle/input/harvestdata/NASAHarvestData.csv'

# Check for a valid filepath to a CSV file in a dataset
step_2.check()
# Out:
# Correct:

# %%
# Fill in the line below: Read the file into a variable my_data
my_data = pd.read_csv(my_filepath)

# Check that a dataset has been uploaded into my_data
step_3.check()
# Out:
# Correct:

# %%
# Print the first five rows of the data
my_data.head()
# Out:
#    ObjectID                              GlobalID   CreationDate  \
# 0         1  91f4ba6f-7786-4fc9-b173-d13f2bd95228  1/10/23 20:11
# 1         2  e0390d4d-8cdf-4651-b377-e5037dd7f5d6  1/17/23 17:45
# 2         3  c68383f6-69d5-4fc9-bb4b-fd27e7fe105d  1/17/23 18:52
# 3         4  ec1491e5-2199-46ad-8423-25115326e2d2  1/17/23 18:52
# 4         5  66e0706a-cf80-49f6-92a3-e788bc1d003f  1/17/23 21:10
#
#                       Creator       EditDate                      Editor  \
# 0           NASAHarvest_UofMD  1/10/23 20:11           NASAHarvest_UofMD
# 1           NASAHarvest_UofMD  1/17/23 17:45           NASAHarvest_UofMD
# 2  NASAHarvestCollector_UofMD  1/17/23 18:52  NASAHarvestCollector_UofMD
# 3  NASAHarvestCollector_UofMD  1/17/23 18:52  NASAHarvestCollector_UofMD
# 4  NASAHarvestCollector_UofMD  1/17/23 21:10  NASAHarvestCollector_UofMD
#
#         Your name What is the date and time of collection?  \
# 0          Ivan Z                            1/10/23 20:04
# ...

# %%
plt.figure(figsize=(10,10))
sns.countplot(x=my_data['Are there no crops (fallow or pasture), one crop, or multiple crops growing in the field?'])

step_4.check()
# Out:
# Correct:
